# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
properties=pd.read_excel("/content/drive/Shareddrives/SDC - BukitVista/data_prepo_v3.xlsx")
properties.head()
# Out:
#    booking_earned_per_day  booking_earned  earn_per_day  property_type  \
# 0                270159.0        540318.0        270159              4
# 1                260154.0        520307.0        260154              4
# 2                311295.0        311295.0        311295              4
# 3                250147.0        250147.0        250147              4
# 4                220130.0        440259.0        220130              4
#
#   area_id  property_bedrooms booking_check_in booking_check_out  duration  \
# 0   A0020                  4       15/06/2023        17/06/2023         2
# 1   A0020                  4       13/07/2023        15/07/2023         2
# 2   A0020                  4       22/07/2023        23/07/2023         1
# 3   A0020                  4       20/04/2023        21/04/2023         1
# 4   A0020                  4       08/06/2023        10/06/2023         2
#
#   day_check_in month_check_in  booking_guest_number  booking_currency  \
# ...

# %%
properties.loc[properties['day_check_in'] == 'Sunday', 'day_check_in'] = 1
properties.loc[properties['day_check_in'] == 'Monday', 'day_check_in'] = 2
properties.loc[properties['day_check_in'] == 'Tuesday', 'day_check_in'] = 3
properties.loc[properties['day_check_in'] == 'Wednesday', 'day_check_in'] = 4
properties.loc[properties['day_check_in'] == 'Thursday', 'day_check_in'] = 5
properties.loc[properties['day_check_in'] == 'Friday', 'day_check_in'] = 6
properties.loc[properties['day_check_in'] == 'Saturday', 'day_check_in'] = 7

# %%
properties.loc[properties['month_check_in'] == 'January', 'month_check_in'] = 1
properties.loc[properties['month_check_in'] == 'February', 'month_check_in'] = 2
properties.loc[properties['month_check_in'] == 'March', 'month_check_in'] = 3
properties.loc[properties['month_check_in'] == 'April', 'month_check_in'] = 4
properties.loc[properties['month_check_in'] == 'May', 'month_check_in'] = 5
properties.loc[properties['month_check_in'] == 'June', 'month_check_in'] = 6
properties.loc[properties['month_check_in'] == 'July', 'month_check_in'] = 7
properties.loc[properties['month_check_in'] == 'August', 'month_check_in'] = 8
properties.loc[properties['month_check_in'] == 'September', 'month_check_in'] = 9
properties.loc[properties['month_check_in'] == 'October', 'month_check_in'] = 10
properties.loc[properties['month_check_in'] == 'November', 'month_check_in'] = 11
properties.loc[properties['month_check_in'] == 'December', 'month_check_in'] = 12

# %%
properties.head()
# Out:
#    booking_earned_per_day  booking_earned  earn_per_day  property_type  \
# 0                270159.0        540318.0        270159              4
# 1                260154.0        520307.0        260154              4
# 2                311295.0        311295.0        311295              4
# 3                250147.0        250147.0        250147              4
# 4                220130.0        440259.0        220130              4
#
#   area_id  property_bedrooms booking_check_in booking_check_out  duration  \
# 0   A0020                  4       15/06/2023        17/06/2023         2
# 1   A0020                  4       13/07/2023        15/07/2023         2
# 2   A0020                  4       22/07/2023        23/07/2023         1
# 3   A0020                  4       20/04/2023        21/04/2023         1
# 4   A0020                  4       08/06/2023        10/06/2023         2
#
#   day_check_in month_check_in  booking_guest_number  booking_currency  \
# ...

# %%
properties.columns
# Out:
# Index(['booking_earned_per_day', 'booking_earned', 'earn_per_day',
#        'property_type', 'area_id', 'property_bedrooms', 'booking_check_in',
#        'booking_check_out', 'duration', 'day_check_in', 'month_check_in',
#        'booking_guest_number', 'booking_currency', 'minimum_rate'],
#       dtype='object')

# %%
area_count=properties["area_id"].value_counts()
area_count
# Out:
# area_id
# A0002    6908
# A0008    4627
# A0003    3905
# A0020    3394
# A0011    1168
# A0027     863
# A0036     781
# A0013     738
# A0010     669
# A0004     496
# A0028     422
# A0031     412
# A0032     363
# A0043     299
# A0012     293
# A0025     274
# A0029     271
# A0037     198
# A0050     172
# A0049     139
# A0035     131
# A0045      97
# A0024      86
# A0022      41
# A0052      39
# A0015      19
# Name: count, dtype: int64

# %%
# Mengurutkan nilai area_id dan memberi label secara urut dari 1
properties['area_id'] = properties['area_id'].rank(method='dense').astype(int)

properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26805 entries, 0 to 26804
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   booking_earned_per_day  26805 non-null  float64
#  1   booking_earned          26805 non-null  float64
#  2   earn_per_day            26805 non-null  int64
#  3   property_type           26805 non-null  int64
#  4   area_id                 26805 non-null  int64
#  5   property_bedrooms       26805 non-null  int64
#  6   booking_check_in        26805 non-null  object
#  7   booking_check_out       26805 non-null  object
#  8   duration                26805 non-null  int64
#  9   day_check_in            26805 non-null  object
#  10  month_check_in          26805 non-null  object
#  11  booking_guest_number    26805 non-null  int64
#  12  booking_currency        26805 non-null  int64
#  13  minimum_rate            26805 non-null  int64
# ...

# %%
properties.head()
# Out:
#    booking_earned_per_day  booking_earned  earn_per_day  property_type  \
# 0                270159.0        540318.0        270159              4
# 1                260154.0        520307.0        260154              4
# 2                311295.0        311295.0        311295              4
# 3                250147.0        250147.0        250147              4
# 4                220130.0        440259.0        220130              4
#
#    area_id  property_bedrooms booking_check_in booking_check_out  duration  \
# 0       10                  4       15/06/2023        17/06/2023         2
# 1       10                  4       13/07/2023        15/07/2023         2
# 2       10                  4       22/07/2023        23/07/2023         1
# 3       10                  4       20/04/2023        21/04/2023         1
# 4       10                  4       08/06/2023        10/06/2023         2
#
#   day_check_in month_check_in  booking_guest_number  booking_currency  \
# ...

# %%
properties = properties.drop(columns=["booking_earned_per_day",	"booking_earned", "booking_check_in",	"booking_check_out", "booking_currency"])

properties.head()
# Out:
#    earn_per_day  property_type  area_id  property_bedrooms  duration  \
# 0        270159              4       10                  4         2
# 1        260154              4       10                  4         2
# 2        311295              4       10                  4         1
# 3        250147              4       10                  4         1
# 4        220130              4       10                  4         2
#
#   day_check_in month_check_in  booking_guest_number  minimum_rate
# 0            5              6                     2        180000
# 1            5              7                     1        180000
# 2            7              7                     1        180000
# 3            5              4                     2        180000
# 4            5              6                     2        180000

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26805 entries, 0 to 26804
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   earn_per_day          26805 non-null  int64
#  1   property_type         26805 non-null  int64
#  2   area_id               26805 non-null  int64
#  3   property_bedrooms     26805 non-null  int64
#  4   duration              26805 non-null  int64
#  5   day_check_in          26805 non-null  object
#  6   month_check_in        26805 non-null  object
#  7   booking_guest_number  26805 non-null  int64
#  8   minimum_rate          26805 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# # Normalisasi

# %%
from sklearn.preprocessing import StandardScaler

# Daftar kolom yang dikecualikan dari normalisasi
columns_to_exclude = [
    'property_type', 'area_id', 'day_check_in', 'month_check_in',
]

# Memisahkan kolom yang akan dinormalisasi dan yang tidak
df_to_normalize = properties.drop(columns=columns_to_exclude)
df_excluded = properties[columns_to_exclude]

# Membuat StandardScaler
scaler = StandardScaler()

# Menormalkan kolom yang dipilih menggunakan Z-score
df_normalized = pd.DataFrame(scaler.fit_transform(df_to_normalize), columns=df_to_normalize.columns)

properties = pd.concat([df_excluded, df_normalized], axis=1)

# %%
properties.head()
# Out:
#    property_type  area_id day_check_in month_check_in  earn_per_day  \
# 0              4       10            5              6     -0.724847
# 1              4       10            5              7     -0.738045
# 2              4       10            7              7     -0.670582
# 3              4       10            5              4     -0.751246
# 4              4       10            5              6     -0.790844
#
#    property_bedrooms  duration  booking_guest_number  minimum_rate
# 0          -0.384885 -0.346873             -0.054102     -0.840348
# 1          -0.384885 -0.346873             -0.798944     -0.840348
# 2          -0.384885 -0.591298             -0.798944     -0.840348
# 3          -0.384885 -0.591298             -0.054102     -0.840348
# 4          -0.384885 -0.346873             -0.054102     -0.840348

# %% [markdown]
# # Train Test

# %%
from sklearn.model_selection import train_test_split

X = properties.drop(["earn_per_day"],axis =1)
y = properties["earn_per_day"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

# %%
print(f'Total # of sample in whole dataset: {len(X)}')
print(f'Total # of sample in train dataset: {len(X_train)}')
print(f'Total # of sample in test dataset: {len(X_test)}')
# Out:
# Total # of sample in whole dataset: 26805
# Total # of sample in train dataset: 21444
# Total # of sample in test dataset: 5361

# %% [markdown]
# Model Development

# %%
# Siapkan dataframe untuk analisis model
models = pd.DataFrame(index=['train_mse', 'test_mse'],
                      columns=['KNN', 'RandomForest', 'Boosting'])

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train, y_train)

models.loc['train_mse','knn'] = mean_squared_error(y_pred = knn.predict(X_train), y_true=y_train)

# %% [markdown]
# Random Forest

# %%
# Impor library yang dibutuhkan
from sklearn.ensemble import RandomForestRegressor

# buat model prediksi
RF = RandomForestRegressor(n_estimators=50, max_depth=16, random_state=55, n_jobs=-1)
RF.fit(X_train, y_train)

models.loc['train_mse','RandomForest'] = mean_squared_error(y_pred=RF.predict(X_train), y_true=y_train)

# %% [markdown]
# AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor

boosting = AdaBoostRegressor(learning_rate=0.05, random_state=55)
boosting.fit(X_train, y_train)
models.loc['train_mse','Boosting'] = mean_squared_error(y_pred=boosting.predict(X_train), y_true=y_train)

# %% [markdown]
# #**Evaluasi Model**

# %%
# Buat variabel mse yang isinya adalah dataframe nilai mse data train dan test pada masing-masing algoritma
mse = pd.DataFrame(columns=['train', 'test'], index=['KNN','RF','Boosting'])

# Buat dictionary untuk setiap algoritma yang digunakan
model_dict = {'KNN': knn, 'RF': RF, 'Boosting': boosting}

# Hitung Mean Squared Error masing-masing algoritma pada data train dan test
for name, model in model_dict.items():
    mse.loc[name, 'train'] = mean_squared_error(y_true=y_train, y_pred=model.predict(X_train))/1e3
    mse.loc[name, 'test'] = mean_squared_error(y_true=y_test, y_pred=model.predict(X_test))/1e3

# Panggil mse
mse
# Out:
#              train      test
# KNN       0.000173  0.000215
# RF        0.000051  0.000177
# Boosting  0.000274  0.000286

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots()
mse.sort_values(by='test', ascending=False).plot(kind='barh', ax=ax, zorder=3)
ax.grid(zorder=0)

# %%
from sklearn.metrics import r2_score

# Buat DataFrame untuk menyimpan nilai R-squared dari data train dan test
rsq = pd.DataFrame(columns=['train', 'test'], index=['KNN', 'RF', 'Boosting'])

# Buat dictionary untuk setiap algoritma yang digunakan
model_dict = {'KNN': knn, 'RF': RF, 'Boosting': boosting}

# Hitung R-squared masing-masing algoritma pada data train dan test
for name, model in model_dict.items():
    rsq.loc[name, 'train'] = r2_score(y_true=y_train, y_pred=model.predict(X_train))
    rsq.loc[name, 'test'] = r2_score(y_true=y_test, y_pred=model.predict(X_test))

# Tampilkan DataFrame rsq
rsq
# Out:
#              train      test
# KNN       0.825157  0.795002
# RF        0.947913  0.830778
# Boosting  0.722996  0.726911

# %%
# Set model as index
#rsq.set_index('model', inplace=True)

fig, ax = plt.subplots()
bars = rsq.plot(kind='barh', ax=ax, zorder=3)

# Tambahkan keterangan nilai pada setiap bar
for i in range(len(rsq)):
    for j in range(len(rsq.columns)):
        value = rsq.iloc[i, j]
        ax.text(value, i + j * 0.3 - 0.15, f'{value:.2f}', va='center', ha='left', zorder=4)

ax.grid(zorder=0)

plt.show()

# %%
X_test.iloc[:1]
# Out:
#        property_type  area_id day_check_in month_check_in  property_bedrooms  \
# 12302              4        1            4             10           1.149148
#
#        duration  booking_guest_number  minimum_rate
# 12302 -0.102448             -0.054102     -0.334566

# %%
# contoh prediksi
prediksi = X_test.iloc[:1].copy()
pred_dict = {'y_true':y_test[:1]}
for name, model in model_dict.items():
    pred_dict['prediksi_'+name] = model.predict(prediksi).round(1)

pd.DataFrame(pred_dict)
# Out:
#          y_true  prediksi_KNN  prediksi_RF  prediksi_Boosting
# 12302 -0.448461          -0.1         -0.3               -0.2

# %%
from sklearn.metrics import mean_squared_error

# Buat DataFrame untuk prediksi
prediksi = X_test.iloc[:1].copy()
pred_dict = {'y_true': y_test.iloc[:1]}  # Menggunakan y_test untuk keperluan dictionary

pred_dict
# Out:
# {'y_true': 12302   -0.448461
#  Name: earn_per_day, dtype: float64}

# %%
y_test.iloc[:1]
# Out:
# 12302   -0.448461
# Name: earn_per_day, dtype: float64

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Asumsikan scaler sudah di-fit dengan data pelatihan sebelumnya
# scaler.fit(training_data)

# Definisikan input pengguna
property_type = int(input("Masukkan jenis properti: "))  # Asumsikan jenis properti sudah dalam bentuk numerik
area_id = int(input("Masukkan ID area: "))
property_bedrooms = int(input("Masukkan jumlah kamar tidur: "))
duration = int(input("Masukkan durasi tinggal (jumlah malam): "))
day_check_in = int(input("Masukkan hari check-in (1-31): "))
month_check_in = int(input("Masukkan bulan check-in (1-12): "))
booking_guest_number = int(input("Masukkan jumlah tamu yang memesan: "))
minimum_rate = float(input("Masukkan tarif minimum: "))

# Buat array dari input pengguna untuk skala minimum_rate
min_rate_input = np.array([[property_bedrooms, duration, booking_guest_number, minimum_rate]])

# Ubah skala minimum_rate menggunakan scaler yang sudah di-fit
minimum_rate_scaled = scaler.transform(min_rate_input)[:, -1][0]

# Gabungkan semua input dalam satu array
user_input = np.array([[property_type, area_id, property_bedrooms, duration, day_check_in, month_check_in, booking_guest_number, minimum_rate_scaled]])

# Lakukan encoding atau pemrosesan tambahan pada input pengguna (misalnya, one-hot encoding untuk property_type)
# Misalnya, jika property_type perlu one-hot encoding, lakukan di sini

# Lakukan prediksi menggunakan model yang telah Anda siapkan sebelumnya
predicted_price_scaled = model.predict(user_input)[0]  # Ambil nilai prediksi pertama dari array

# Bulatkan hasil prediksi sebelum menampilkannya kepada pengguna
predicted_price_rounded = round(predicted_price_scaled, 2)

# Tampilkan prediksi kepada pengguna
print("Prediksi harga: ", predicted_price_rounded)
# Out:
# Masukkan jenis properti: 1
# Masukkan ID area: 2
# Masukkan jumlah kamar tidur: 4
# Masukkan durasi tinggal (jumlah malam): 3
# Masukkan hari check-in (1-31): 2
# Masukkan bulan check-in (1-12): 1
# Masukkan jumlah tamu yang memesan: 2
# Masukkan tarif minimum: 1000000
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3f92baf23029> in <cell line: 21>()
#      19
#      20 # Ubah skala minimum_rate menggunakan scaler yang sudah di-fit
# ---> 21 minimum_rate_scaled = scaler.transform(min_rate_input)[:, -1][0]
#      22
#      23 # Gabungkan semua input dalam satu array
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
# ...

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# Asumsikan scaler sudah di-fit dengan data pelatihan sebelumnya
# scaler.fit(training_data)

# Definisikan input pengguna
property_type = int(input("Masukkan jenis properti: "))  # Asumsikan jenis properti sudah dalam bentuk numerik
area_id = int(input("Masukkan ID area: "))
property_bedrooms = int(input("Masukkan jumlah kamar tidur: "))
duration = int(input("Masukkan durasi tinggal (jumlah malam): "))
day_check_in = int(input("Masukkan hari check-in (1-31): "))
month_check_in = int(input("Masukkan bulan check-in (1-12): "))
booking_guest_number = int(input("Masukkan jumlah tamu yang memesan: "))
minimum_rate = float(input("Masukkan tarif minimum: "))

# Buat array dari input pengguna untuk skala minimum_rate
min_rate_input = np.array([[property_bedrooms, duration, booking_guest_number, minimum_rate]])

# Ubah skala minimum_rate menggunakan scaler yang sudah di-fit
minimum_rate_scaled = scaler.transform(min_rate_input)[:, -1][0]

# Gabungkan semua input dalam satu array
user_input = np.array([[property_type, area_id, property_bedrooms, duration, day_check_in, month_check_in, booking_guest_number, minimum_rate_scaled]])

# Lakukan encoding atau pemrosesan tambahan pada input pengguna (misalnya, one-hot encoding untuk property_type)
# Misalnya, jika property_type perlu one-hot encoding, lakukan di sini

# Lakukan prediksi menggunakan model yang telah Anda siapkan sebelumnya
predicted_price_scaled = model.predict(user_input)

# Lakukan inversi transformasi untuk mengembalikan prediksi ke nilai tanpa normalisasi
# Asumsikan predicted_price_scaled adalah array 1D dengan satu nilai
predicted_price = scaler.inverse_transform(np.array([[0, 0, 0, predicted_price_scaled[0]]]))[:, -1][0]

# Bulatkan hasil prediksi sebelum menampilkannya kepada pengguna
predicted_price_rounded = round(predicted_price, 0)

# Tampilkan prediksi kepada pengguna
print("Prediksi harga: ", predicted_price_rounded)
# Out:
# Masukkan jenis properti: 4
# Masukkan ID area: 10
# Masukkan jumlah kamar tidur: 4
# Masukkan durasi tinggal (jumlah malam): 2
# Masukkan hari check-in (1-31): 5
# Masukkan bulan check-in (1-12): 6
# Masukkan jumlah tamu yang memesan: 2
# Masukkan tarif minimum: 180000
# Prediksi harga:  19999999.0
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 4	10	4	2	5	6	2	180000
